# %%
import numpy as np
import matplotlib.pylab as plt
import pandas as pd
# %pylab inline
# Out:
# /usr/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 216, got 192
#   return f(*args, **kwds)
# Populating the interactive namespace from numpy and matplotlib
# /home/sheng/.local/lib/python3.6/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['plt']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
def printdata(datafile, length):
    data = fromfile(datafile)
    imshow(np.log(data.reshape(length, -1)), cmap=cm.Oranges, aspect='auto', vmin=-15, vmax=-8)
    return

def density(datafile, length, rmin, rmax):
    data = fromfile(datafile)
    dens = data.reshape(length, -1).sum(axis=1)
    xl = np.linspace(rmin, rmax, len(dens))
    plt.plot(xl, dens, 'k')

# %%
plt.figure(figsize=(10, 10))
printdata('single/outputs/fargo_multifluid_single/dust1dens20.dat', 512)
plt.colorbar()
plt.savefig('s.png')

# %%
plt.figure(figsize=(10, 10))
printdata('couple/outputs/fargo_multifluid_couple/dust1dens20.dat', 512)
plt.colorbar()
plt.savefig('c.png')

# %%
density('single/outputs/fargo_multifluid_single/dust1dens20.dat', 512, 0.1, 2.0)
plt.savefig('sd.png')

# %%
density('couple/outputs/fargo_multifluid_couple/dust1dens20.dat', 512, 0.1, 2.0)
plt.savefig('cd.png')

# %%
ls
# Out:
#  couple/              fargo_m/           'public (copy)'/
#  fargo3d-1.3/         fargo_multifluid/   single/
#  fargo3d-1.3.tar.gz   iraf/               未命名.ipynb
